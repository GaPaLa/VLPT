# %%
# inspired by VPT cleaning process, use model, preprocess = clip.load('RN50x64', device, jit=True)
#!pip install matplotlib
#!pip install -U yt-dlp
#!pip install ffmpeg-python

# %%
import yt_dlp
import matplotlib
from yt_dlp import YoutubeDL

# %%
# OPEN VIDEO FILE HEADER, READ SEEN LINKS/CHANNELS
header_file = open("spamham_samples/header.txt", "r")
header_text = header_file.readlines()
header_file.close()

all_links = []
all_channels = []

# https://pypi.org/project/yt-dlp/#usage-and-options
def longer_than_a_minute(info, *, incomplete):
    """Download only videos longer than 10 minutes"""
    duration = info.get('duration')
    if duration and duration < 600:
        return 'The video is too short'
YDL_OPTIONS = {'noplaylist':True, 'Download':False, 'match_filter':longer_than_a_minute, 'ignoreerrors':True}

for line in header_text:
    link = line
    if (not (link in all_links)) and (link!=''):
        all_links.append(link)

# %%
#from requests import get

# minecraft tutorial how to survival vanilla new world lets play 1.16",
# minecraft tutorial how to hardcore vanilla new world lets play 1.16",

search_query = "minecraft vanilla lets play stream"

#"minecraft new world creative vanilla"
#"minecraft creative mode how to"
#"minecraft guide walkthrough survival new world 1.16"
#"minecraft survival hardcore tutorial how to guide learn basics beginner lets play walkthrough gameplay new world first night first day 1.16"
# "minecraft shaders"
#"minecraft console edition pocket edition ps3 ps4 ps5 xbox bedrock"
#"playing minecraft with multiplayer server"
# minecraft creative 1.16
# minecraft creative
# minecraft lets play stream mod
# minecraft mod technic
# minecraft mod

with yt_dlp.YoutubeDL(YDL_OPTIONS) as ydl:
    search_results = ydl.extract_info(f"ytsearchall:{search_query}", download=False)['entries']
# Out:
# [youtube:search] Extracting URL: ytsearchall:minecraft vanilla lets play stream
# [download] Downloading playlist: minecraft vanilla lets play stream
# [youtube:search] query "minecraft vanilla lets play stream": Downloading web client config
# [youtube:search] query "minecraft vanilla lets play stream" page 1: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 2: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 3: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 4: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 5: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 6: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 7: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 8: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 9: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 10: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 11: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 12: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 13: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 14: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 15: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 16: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 17: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 18: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 19: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 20: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 21: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 22: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 23: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 24: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 25: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 26: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 27: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 28: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 29: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 30: Downloading API JSON
# [youtube:search] query "minecraft vanilla lets play stream" page 31: Downloading API JSON
# [youtube:search] Playlist minecraft vanilla lets play stream: Downloading 565 items of 565
# [download] Downloading item 1 of 565
# [youtube] Extracting URL: https://www.youtube.com/watch?v=awMblI7IGuw
# [youtube] awMblI7IGuw: Downloading webpage
# [youtube] awMblI7IGuw: Downloading android player API JSON
# [download] Downloading item 2 of 565
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RFRkVBGHH2w
# [youtube] RFRkVBGHH2w: Downloading webpage
# [youtube] RFRkVBGHH2w: Downloading android player API JSON
# [download] Downloading item 3 of 565
# [youtube] Extracting URL: https://www.youtube.com/watch?v=V-4sLymIv0M
# [youtube] V-4sLymIv0M: Downloading webpage
# [youtube] V-4sLymIv0M: Downloading android player API JSON
# [download] Downloading item 4 of 565
# [youtube] Extracting URL: https://www.youtube.com/watch?v=p5QoLGb0NmM
# [youtube] p5QoLGb0NmM: Downloading webpage
# [youtube] p5QoLGb0NmM: Downloading android player API JSON
# [download] Downloading item 5 of 565
# [youtube] Extracting URL: https://www.youtube.com/watch?v=pgxNuVGktww
# [youtube] pgxNuVGktww: Downloading webpage
# [youtube] pgxNuVGktww: Downloading android player API JSON
# [download] Downloading item 6 of 565
# [youtube] Extracting URL: https://www.youtube.com/watch?v=u0oqnHlYzZw
# [youtube] u0oqnHlYzZw: Downloading webpage
# [youtube] u0oqnHlYzZw: Downloading android player API JSON
# [download] Downloading item 7 of 565
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0FZot2kd1Ls
# [youtube] 0FZot2kd1Ls: Downloading webpage
# [youtube] 0FZot2kd1Ls: Downloading android player API JSON
# [download] Downloading item 8 of 565
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BvPwKtAAJ_M
# [youtube] BvPwKtAAJ_M: Downloading webpage
# [youtube] BvPwKtAAJ_M: Downloading android player API JSON
# [download] Downloading item 9 of 565
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uryOX5rpUCQ
# [youtube] uryOX5rpUCQ: Downloading webpage
# [youtube] uryOX5rpUCQ: Downloading android player API JSON
# [download] Downloading item 10 of 565
# [youtube] Extracting URL: https://www.youtube.com/shorts/YfKSShhl9M8
# [youtube] YfKSShhl9M8: Downloading webpage
# [youtube] YfKSShhl9M8: Downloading android player API JSON
# [download] The video is too short
# [download] Downloading item 11 of 565
# [youtube] Extracting URL: https://www.youtube.com/shorts/ovC7JbDC1I0
# [youtube] ovC7JbDC1I0: Downloading webpage
# [youtube] ovC7JbDC1I0: Downloading android player API JSON
# [download] The video is too short
# [download] Downloading item 12 of 565
# [youtube] Extracting URL: https://www.youtube.com/shorts/B_K12-7oEls
# [youtube] B_K12-7oEls: Downloading webpage
# [youtube] B_K12-7oEls: Downloading android player API JSON
# [download] The video is too short
# [download] Downloading item 13 of 565
# [youtube] Extracting URL: https://www.youtube.com/shorts/eUr57ZDYNq4
# [youtube] eUr57ZDYNq4: Downloading webpage
# [youtube] eUr57ZDYNq4: Downloading android player API JSON
# [download] The video is too short
# [download] Downloading item 14 of 565
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BsJJUAGoFBc
# [youtube] BsJJUAGoFBc: Downloading webpage
# [youtube] BsJJUAGoFBc: Downloading android player API JSON
# [download] Downloading item 15 of 565
# [youtube] Extracting URL: https://www.youtube.com/watch?v=WK5XYG-dH-k
# [youtube] WK5XYG-dH-k: Downloading webpage
# [youtube] WK5XYG-dH-k: Downloading android player API JSON
# [download] Downloading item 16 of 565
# [youtube] Extracting URL: https://www.youtube.com/watch?v=q9E4U39BQSg
# [youtube] q9E4U39BQSg: Downloading webpage
# [youtube] q9E4U39BQSg: Downloading android player API JSON
# [download] Downloading item 17 of 565
# [youtube] Extracting URL: https://www.youtube.com/watch?v=CKker83XzG4
# [youtube] CKker83XzG4: Downloading webpage
# [youtube] CKker83XzG4: Downloading android player API JSON

# %%
def s_to_HHmmss(secs):
    mins = (secs - secs%60) / 60
    secs = secs%60
    hours = (mins - mins%60) / 60
    mins = mins%60
    
    if hours>0:
        HHmmss = ":".join([str(int(hours)),str(int(mins)),str(secs)])
    elif mins>0:
        HHmmss = ":".join([str(int(mins)),str(secs)])
    else:
        HHmmss = str(secs)
            
    return HHmmss

# %%
# DOWNLOAD RANDOM FRAMES FROM EACH LINK
import random
import os
#https://pypi.org/project/yt-dlp/



# dont re-download frames from videos which have already hadframes downloaded
with open("spamham_samples/header.txt","r") as used_links:
    used_links = used_links.readlines()
    for i in range(len(used_links)):
        used_links[i] = used_links[i].split('\n')[0]




# for every link:
for i in range(len(search_results)):

    
    # separate out video info
    video = search_results[i]
    try:
        video['duration']
    except:
        continue

    if video['duration']>300 and not(video['id'] in used_links):      ############################# PRE-FILTERING FILTERING:

        video_link = video['id']
        video_name = video['title']
        video_channel = video['channel']
        filename = video_link

        print("getting new video!")
        # SELECT RANDOM FRAME
        duration = video['duration']
        random_sec = min(random.randint(0, 10*60), duration-2)
        random_sec_formatted = "*"+s_to_HHmmss(random_sec)+"-"+s_to_HHmmss(random_sec+1)


        # DOWNLOAD SHORT VIDEO SECTION
        full_link = str("https://www.youtube.com/watch?v=%s"%video_link)
        print(full_link)
        print(random_sec_formatted)

        filename_ext = filename+'.mp4'
        command_download_frames = str("yt-dlp -S res:720,ext:mp4,fps:24 -c --recode mp4 --download-sections %s %s --output spamham_samples/%s.mp4" %(random_sec_formatted, full_link, filename))
        #command_get_1_frame = str('ffmpeg -i spamham_samples/%s -vcodec png -ss 0 -vframes 1 -an -f rawvideo spamham_samples/frames/%s.png -y' %(filename_ext, filename) )
        command_get_1_frame = str('ffmpeg -i spamham_samples/%s -r 1 -vframes 1 -f image2 -q:v 1 spamham_samples/frames/%s.jpeg -y' %(filename_ext, filename) )
        command_del_video = str('rm spamham_samples/%s.mp4' %filename)
        command_all_in_1 = command_download_frames +' && ' + command_get_1_frame +' && ' + command_del_video
        os.system(command_all_in_1)

        # CROP VIDEO SECTION TO FIRST FRAME
        #"https://www.youtube.com/watch?v={sID}".format(sID=video_link)
        #label = get_response(filename+".jpg")
        line = str(filename+"\n")

        header_file = open("spamham_samples/header.txt","a")
        sources_file = open("spamham_samples/sources.txt","a")
        header_file.write(line)
        sources_file.write(video_channel+","+"https://www.youtube.com/watch?v={sID}".format(sID=video_link)+"\n")
        header_file.close()
        sources_file.close()
